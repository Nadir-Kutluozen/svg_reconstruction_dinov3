# %%
import streamlit

# %%
# Out:
# 2026-05-04 18:35:39.987
# ...
#   command:
#
#     streamlit run /grid/it/data/elzar/easybuild/software/Anaconda3/2024.02-1/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
